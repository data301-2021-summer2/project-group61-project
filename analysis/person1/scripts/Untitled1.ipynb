# %%
import pandas as pd
import numpy as np

# %%
# Method chaining begins
def load_and_process(url):
    df = (
        data
        .drop(columns=['Positive affect', 'Negative affect'])
        .loc[lambda x: x['year']>2015]
        .sort_values("Life Ladder", ascending=False)
        .dropna(axis='rows', thresh =8).reset_index(drop=True)
        .reset_index(drop=True)
    
    )

    return df

# %%
data = pd.read_csv('/Users/Khalidmahmoud/Desktop/DATA301/project-group61-project/data/raw/world-happiness-report.csv') # this a data file that gets loaded
load_and_process(data)
# Out:
#                  Country name  year  Life Ladder  Log GDP per capita  \
# 0                     Finland  2020        7.889              10.750
# 1                     Finland  2018        7.858              10.783
# 2                     Finland  2017        7.788              10.768
# 3                     Finland  2019        7.780              10.792
# 4                 Switzerland  2019        7.694              11.136
# ..                        ...   ...          ...                 ...
# 639               Afghanistan  2018        2.694               7.692
# 640                  Zimbabwe  2019        2.694               7.950
# 641  Central African Republic  2016        2.693               6.785
# 642               Afghanistan  2017        2.662               7.697
# 643               Afghanistan  2019        2.375               7.697
#
#      Social support  Healthy life expectancy at birth  \
# 0             0.962                              72.1
# ...

# %%
temp = {'Fruits': ["apple", "banana", "grapefruit"], 'Mass (g)': [50,30,45]}

# %%
pd.DataFrame.from_dict(temp)
# Out:
#        Fruits  Mass (g)
# 0       apple        50
# 1      banana        30
# 2  grapefruit        45
